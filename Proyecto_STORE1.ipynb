# %% [markdown]
# # Proyecto STORE 1
#
# Se ha recibido una base de datos cruda con información de clientes y sus compras. El objetivo es limpiar y procesar estos datos para poder responder a preguntas clave del negocio como identificar clientes leales, analizar ingresos por categoría, y encontrar oportunidades de marketing segmentado.

# %% [markdown]
# ## Introducción de los datos
#
# La tienda Store 1 almacena información de sus usuarios en listas anidadas. Cada sublista contiene:
#
# - `user_id`: identificador único
# - `user_name`: nombre y apellido en un solo string
# - `user_age`: edad
# - `fav_categories`: categorías favoritas de compra (mayúsculas)
# - `total_spendings`: montos correspondientes a cada categoría

# %% [markdown]
# ## Limpieza inicial de un registro de cliente
#
# Entenderemos los elementos clave de un registro antes de escalar el proceso al resto de los usuarios.
#
# Aplicaremos las siguientes transformaciones:
#
# 1. Eliminar espacios en blanco y guiones bajos (`_`) del nombre del usuario.
# 2. Dividir el nombre en una lista separando nombre y apellido.
# 3. Convertir la edad del usuario a un número entero.

# %%
# Declarar una variable de ejemplo user donde se almacenan los datos del cliente 
user = ['32415', ' mike_reed ', 32.0, ['ELECTRONICS', 'SPORT', 'BOOKS'], [894, 213, 173]]

# Limpiar y dividir el nombre
user[1] = user[1].strip()
user[1] = user[1].replace("_"," ")

# Dividir el nombre en una lista
user[1]  = user[1].split()

# Convertir la edad a entero
user[2] = int(user[2])

# Mostrar resultado
print(user)

# %% [markdown]
# ## Convertir las categorías a minúsculas
#
# En los datos actuales, las categorías favoritas de los clientes están escritas completamente en mayúsculas. Este formato puede causar inconsistencias en análisis posteriores, como al agrupar, filtrar o contar categorías. Para garantizar una lectura uniforme y facilitar futuras operaciones, es necesario normalizar estos valores a minúsculas.
#
# En este paso, trabajaremos con una lista de ejemplo llamada fav_categories y construiremos una nueva lista llamada fav_categories_low, que contendrá las versiones en minúsculas de cada categoría.

# %%
# Lista original de categorías favoritas escritas en mayúsculas
fav_categories = ['ELECTRONICS', 'SPORT', 'BOOKS']

# Lista vacía donde almacenaremos las categorías convertidas a minúsculas
fav_categories_low = []

# Recorremos cada categoría en la lista original
for category in fav_categories:
    # Convertimos la categoría a minúscula utilizando el método lower()
    lowered_category = category.lower()

    # Agregamos la categoría convertida a la nueva lista
    fav_categories_low.append(lowered_category)

# Mostramos en pantalla la lista resultante con las categorías en minúsculas
print(fav_categories_low)

# %% [markdown]
# ## Limpieza completa de un usuario
#
# Ahora vamos a empaquetar todo el proceso anterior dentro de una función reutilizable.
#
# Crearemos una función llamada `clean_user(user)` que realice las siguientes acciones:
#
# 1. Limpie espacios y guiones del nombre y lo divida en nombre/apellido.
# 2. Convierta la edad a entero.
# 3. Convierta las categorías a minúsculas.

# %%
# Declarar la función
def clean_user(user):
    # Limpiar y dividir el nombre
    name = user[1].strip().replace("_"," ").lower().split()

    # Convertir la edad como entero
    age = int(user[2])

    # Convertir las categorías a minúsculas dentro de un bucle
    categories = []
    for cat in user[3]:
        categories.append(cat.lower())

    return [user[0], name, age, categories, user[4]]

# Prueba
test_user = ['32415', ' mike_reed ', 32.0, ['ELECTRONICS', 'SPORT', 'BOOKS'], [894, 213, 173]]
print(clean_user(test_user))

# %% [markdown]
# Se ha ejecutado correctamente la función que nos permite automatizar la limpieza de datos (quitar espacios y anidar en una lista, convertir a número entero y pasar las categorías a minúsculas)

# %% [markdown]
# ## Limpieza de toda la base de usuarios
#
# Ahora que tenemos la función `clean_user()` funcionando correctamente, la aplicaremos a todos los registros de clientes.
#
# 1. Iteraremos sobre la lista `users_raw`
# 2. Usaremos la función `clean_user()` para limpiar cada usuario
# 3. Guardaremos los resultados en una nueva lista llamada `users_clean`

# %%
# Lista con los registros de todos los clientes
users_raw = [
    ['32415', ' mike_reed ', 32.0, ['ELECTRONICS', 'SPORT', 'BOOKS'], [894, 213, 173]],
    ['31980', 'kate morgan', 24.0, ['CLOTHES', 'BOOKS'], [439, 390]],
    ['32156', ' john doe ', 37.0, ['ELECTRONICS', 'HOME', 'FOOD'], [459, 120, 99]],
    ['32761', 'SAMANTHA SMITH', 29.0, ['CLOTHES', 'ELECTRONICS', 'BEAUTY'], [299, 679, 85]],
    ['32984', 'David White', 41.0, ['BOOKS', 'HOME', 'SPORT'], [234, 329, 243]],
    ['33001', 'emily brown', 26.0, ['BEAUTY', 'HOME', 'FOOD'], [213, 659, 79]],
    ['33767', ' Maria Garcia', 33.0, ['CLOTHES', 'FOOD', 'BEAUTY'], [499, 189, 63]],
    ['33912', 'JOSE MARTINEZ', 22.0, ['SPORT', 'ELECTRONICS', 'HOME'], [259, 549, 109]],
    ['34009', 'lisa wilson ', 35.0, ['HOME', 'BOOKS', 'CLOTHES'], [329, 189, 329]],
    ['34278', 'James Lee', 28.0, ['BEAUTY', 'CLOTHES', 'ELECTRONICS'], [189, 299, 579]]
]
# Lista donde se guardarán todos los usuarios limpios
users_clean = []

# Bucle para iterar sobre la lista users_raw utilizando la función clean_user 
for i in users_raw:
    cleaned_user = clean_user(i)
    users_clean.append(cleaned_user)

print(users_clean)

# %% [markdown]
# Observamos que se ha ejecutado la función para limpiar todos los usuarios

# %% [markdown]
# ## Calcular ingresos totales
#
# Ahora que tenemos los registros de clientes limpios, generaremos insights que puedan ayudar a la empresa a tomar decisiones estratégicas.
#
# La empresa desea conocer sus ingresos totales por lo que calcularemos los ingresos de la siguiente manera:
#
# 1. Crearemos una variable `revenue` con valor inicial 0 para ir sumando el ingreso de cada cliente.
# 2. Iteraremos sobre la lista `users_clean` con un bucle `for`.
# 3. En cada iteración, extraeremos la lista de gastos de cada usuario.
# 4. Utilizaremos la función integrada `sum()` para los valores y los añadiremos a `revenue`.

# %%
users_clean = [['32415', ['mike', 'reed'], 32, ['electronics', 'sport', 'books'], [894, 213, 173]],
         			 ['31980', ['kate', 'morgan'], 24, ['clothes', 'books'], [439, 390]],
         			 ['32156', ['john', 'doe'], 37, ['electronics', 'home', 'food'], [459, 120, 99]],
         			 ['32761', ['samantha', 'smith'], 29, ['clothes', 'electronics', 'beauty'], [299, 679, 85]],
         			 ['32984', ['david', 'white'], 41, ['books', 'home', 'sport'], [234, 329, 243]],
         			 ['33001', ['emily', 'brown'], 26, ['beauty', 'home', 'food'], [213, 659, 79]],
         			 ['33767', ['maria', 'garcia'], 33, ['clothes', 'food', 'beauty'], [499, 189, 63]],
         			 ['33912', ['jose', 'martinez'], 22, ['sport', 'electronics', 'home'], [259, 549, 109]],
         			 ['34009', ['lisa', 'wilson'], 35, ['home', 'books', 'clothes'], [329, 189, 329]],
         			 ['34278', ['james', 'lee'], 28, ['beauty', 'clothes', 'electronics'], [189, 299, 579]]]

revenue = 0 
for ingresos in users_clean:
    ingreso = sum(ingresos[4])
    revenue += ingreso

print('Total de ingresos:', revenue)

# %% [markdown]
# ## Filtrar a usuarios menores de 30 años
#
# El equipo de marketing quiere segmentar a los usuarios jóvenes para campañas específicas.
#
# Recorreremos la lista de usuarios `users_clean` que se preparó anteriormente y mostraremos los nombres de los clientes menores de 30 años.
#
#
# 1. Mediante un bucle `for` se recorrerá cada usuario en `users_clean`.
# 2. Agregaremos la condición `if` para seleccionar a los usuarios menores de 30 años.

# %%
users_clean = [['32415', ['mike', 'reed'], 32, ['electronics', 'sport', 'books'], [894, 213, 173]],
         			 ['31980', ['kate', 'morgan'], 24, ['clothes', 'books'], [439, 390]],
         			 ['32156', ['john', 'doe'], 37, ['electronics', 'home', 'food'], [459, 120, 99]],
         			 ['32761', ['samantha', 'smith'], 29, ['clothes', 'electronics', 'beauty'], [299, 679, 85]],
         			 ['32984', ['david', 'white'], 41, ['books', 'home', 'sport'], [234, 329, 243]],
         			 ['33001', ['emily', 'brown'], 26, ['beauty', 'home', 'food'], [213, 659, 79]],
         			 ['33767', ['maria', 'garcia'], 33, ['clothes', 'food', 'beauty'], [499, 189, 63]],
         			 ['33912', ['jose', 'martinez'], 22, ['sport', 'electronics', 'home'], [259, 549, 109]],
         			 ['34009', ['lisa', 'wilson'], 35, ['home', 'books', 'clothes'], [329, 189, 329]],
         			 ['34278', ['james', 'lee'], 28, ['beauty', 'clothes', 'electronics'], [189, 299, 579]]]

for edad in users_clean:
    if edad[2] < 30:
        print('Usuarios menor a 30 años:', edad[1][0])

# %% [markdown]
# Hemos podido observar que del total de los registros de Store 1, 5 de sus clientes son menor a 30 años.

# %% [markdown]
# ### Jóvenes con alto gasto
#
# Ahora filtraremos a los usuarios jóvenes que también han gastado mucho dinero, para que la empresa pueda identificarlos y darles beneficios especiales.

# %%
users_clean = [['32415', ['mike', 'reed'], 32, ['electronics', 'sport', 'books'], [894, 213, 173]],
         			 ['31980', ['kate', 'morgan'], 24, ['clothes', 'books'], [439, 390]],
         			 ['32156', ['john', 'doe'], 37, ['electronics', 'home', 'food'], [459, 120, 99]],
         			 ['32761', ['samantha', 'smith'], 29, ['clothes', 'electronics', 'beauty'], [299, 679, 85]],
         			 ['32984', ['david', 'white'], 41, ['books', 'home', 'sport'], [234, 329, 243]],
         			 ['33001', ['emily', 'brown'], 26, ['beauty', 'home', 'food'], [213, 659, 79]],
         			 ['33767', ['maria', 'garcia'], 33, ['clothes', 'food', 'beauty'], [499, 189, 63]],
         			 ['33912', ['jose', 'martinez'], 22, ['sport', 'electronics', 'home'], [259, 549, 109]],
         			 ['34009', ['lisa', 'wilson'], 35, ['home', 'books', 'clothes'], [329, 189, 329]],
         			 ['34278', ['james', 'lee'], 28, ['beauty', 'clothes', 'electronics'], [189, 299, 579]]]

for usuarios in users_clean:
	# cálculo total del gasto por cada usuario
    gasto = sum(usuarios[4]) 
	# condición para mostrar sólo a los usuarios menores de 30 y con un gasto superior a $1000
    if gasto > 1000 and usuarios[2] < 30: 
        print(usuarios[1][0])

# %% [markdown]
# De los 5 usuarios menores a 30 años, 2 de ellos gastan mas de $1000

# %% [markdown]
# ### Usuarios que compraron ropa
#
# Store 1 también está explorando patrones de compra por categoría. Comenzaremos con la categoría `"clothes"`.
#
# Por medio de un bucle recorreremos cada usuario en `users_clean`, dentro del bucle asignaremos una condición para únicamente verificar si `"clothes"` esta entre las categorías compradas.

# %%
users_clean = [['32415', ['mike', 'reed'], 32, ['electronics', 'sport', 'books'], [894, 213, 173]],
         			 ['31980', ['kate', 'morgan'], 24, ['clothes', 'books'], [439, 390]],
         			 ['32156', ['john', 'doe'], 37, ['electronics', 'home', 'food'], [459, 120, 99]],
         			 ['32761', ['samantha', 'smith'], 29, ['clothes', 'electronics', 'beauty'], [299, 679, 85]],
         			 ['32984', ['david', 'white'], 41, ['books', 'home', 'sport'], [234, 329, 243]],
         			 ['33001', ['emily', 'brown'], 26, ['beauty', 'home', 'food'], [213, 659, 79]],
         			 ['33767', ['maria', 'garcia'], 33, ['clothes', 'food', 'beauty'], [499, 189, 63]],
         			 ['33912', ['jose', 'martinez'], 22, ['sport', 'electronics', 'home'], [259, 549, 109]],
         			 ['34009', ['lisa', 'wilson'], 35, ['home', 'books', 'clothes'], [329, 189, 329]],
         			 ['34278', ['james', 'lee'], 28, ['beauty', 'clothes', 'electronics'], [189, 299, 579]]]


for category in users_clean:
    name = category[1][0]
    age = category[2]
    if "clothes" in category[3]:
        print(f"{name} {age}")

# %% [markdown]
# Contamos con 5 usuarios que realizan compras en la categoría clothes

# %% [markdown]
# ### Función con filtro por categoría
#
# Para automatizar el análisis por categoría, implementaremos una función reutilizable que permita obtener los clientes que hayan comprado en una categoría específica.

# %%
users_clean = [['32415', ['mike', 'reed'], 32, ['electronics', 'sport', 'books'], [894, 213, 173]],
         			 ['31980', ['kate', 'morgan'], 24, ['clothes', 'books'], [439, 390]],
         			 ['32156', ['john', 'doe'], 37, ['electronics', 'home', 'food'], [459, 120, 99]],
         			 ['32761', ['samantha', 'smith'], 29, ['clothes', 'electronics', 'beauty'], [299, 679, 85]],
         			 ['32984', ['david', 'white'], 41, ['books', 'home', 'sport'], [234, 329, 243]],
         			 ['33001', ['emily', 'brown'], 26, ['beauty', 'home', 'food'], [213, 659, 79]],
         			 ['33767', ['maria', 'garcia'], 33, ['clothes', 'food', 'beauty'], [499, 189, 63]],
         			 ['33912', ['jose', 'martinez'], 22, ['sport', 'electronics', 'home'], [259, 549, 109]],
         			 ['34009', ['lisa', 'wilson'], 35, ['home', 'books', 'clothes'], [329, 189, 329]],
         			 ['34278', ['james', 'lee'], 28, ['beauty', 'clothes', 'electronics'], [189, 299, 579]]]

def get_clients_by_category(usuario, categoria):
	result = []
	for usuarios in users_clean:
		gasto_usuario = sum(usuarios[4]) #Suma el gasto por usuario
		if categoria in usuarios[3]: #Se valida si existe la categoría en users_clean
			result.append([usuarios[0:3], gasto_usuario]) #En caso de existir usuarios con categoria "home" los agrega a la lista result
	return result

# Prueba de la función con la categoría 'home'
filtered = get_clients_by_category(users_clean, 'home')
print(filtered)

# %% [markdown]
# Hemos podido desarrollar una función reutilizable, la cual nos permite segmentar a los clientes con mayor gasto (leales) y compras por categoría. Esto permitirá al equipo de marketing la segmentación de los clientes y encontrar oportunidades de mercado.
